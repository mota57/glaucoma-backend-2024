# %%
from pynamodb.models import Model
from pynamodb.attributes import (
    UnicodeAttribute, NumberAttribute, UnicodeSetAttribute, UTCDateTimeAttribute
)



class Thread2(Model):
    class Meta:
        table_name = 'Thread2'
        # Specifies the region
        region = 'us-east-1'
    forum_name = UnicodeAttribute(hash_key=True)
    subject = UnicodeAttribute(range_key=True)
    views = NumberAttribute(default=0)
    replies = NumberAttribute(default=0)
    answered = NumberAttribute(default=0)
    tags = UnicodeSetAttribute()
    last_post_datetime = UTCDateTimeAttribute()


Thread2.exists()
#if not Thread.exists():
#    res = Thread.create_table(read_capacity_units=1, write_capacity_units=1, wait=True)
# Out:
# ---------------------------------------------------------------------------
# NoCredentialsError                        Traceback (most recent call last)
# File /workspace/glaucoma-backend-2024/.venv/lib/python3.10/site-packages/pynamodb/connection/base.py:626, in Connection.describe_table(self, table_name)
#     625 try:
# --> 626     data = self.dispatch(DESCRIBE_TABLE, operation_kwargs)
#     627     table_data = data.get(TABLE_KEY)
#
# File /workspace/glaucoma-backend-2024/.venv/lib/python3.10/site-packages/pynamodb/connection/base.py:312, in Connection.dispatch(self, operation_name, operation_kwargs)
#     311 self.send_pre_boto_callback(operation_name, req_uuid, table_name)
# --> 312 data = self._make_api_call(operation_name, operation_kwargs)
#     313 self.send_post_boto_callback(operation_name, req_uuid, table_name)
#
# File /workspace/glaucoma-backend-2024/.venv/lib/python3.10/site-packages/pynamodb/connection/base.py:340, in Connection._make_api_call(self, operation_name, operation_kwargs)
#     339 try:
# --> 340     return self.client._make_api_call(operation_name, operation_kwargs)
#     341 except ClientError as e:
#
# File /workspace/glaucoma-backend-2024/.venv/lib/python3.10/site-packages/botocore/client.py:1005, in BaseClient._make_api_call(self, operation_name, api_params)
#    1004     apply_request_checksum(request_dict)
# -> 1005     http, parsed_response = self._make_request(
#    1006         operation_model, request_dict, request_context
#    1007     )
#    1009 self.meta.events.emit(
#    1010     f'after-call.{service_id}.{operation_name}',
#    1011     http_response=http,
#    (...)
#    1014     context=request_context,
#    1015 )
#
# File /workspace/glaucoma-backend-2024/.venv/lib/python3.10/site-packages/botocore/client.py:1029, in BaseClient._make_request(self, operation_model, request_dict, request_context)
#    1028 try:
# -> 1029     return self._endpoint.make_request(operation_model, request_dict)
#    1030 except Exception as e:
#
# File /workspace/glaucoma-backend-2024/.venv/lib/python3.10/site-packages/botocore/endpoint.py:119, in Endpoint.make_request(self, operation_model, request_dict)
#     114 logger.debug(
#     115     "Making request for %s with params: %s",
#     116     operation_model,
#     117     request_dict,
#     118 )
# --> 119 return self._send_request(request_dict, operation_model)
#
# File /workspace/glaucoma-backend-2024/.venv/lib/python3.10/site-packages/botocore/endpoint.py:196, in Endpoint._send_request(self, request_dict, operation_model)
#     195 self._update_retries_context(context, attempts)
# --> 196 request = self.create_request(request_dict, operation_model)
#     197 success_response, exception = self._get_response(
#     198     request, operation_model, context
#     199 )
#
# File /workspace/glaucoma-backend-2024/.venv/lib/python3.10/site-packages/botocore/endpoint.py:132, in Endpoint.create_request(self, params, operation_model)
#     131     event_name = f'request-created.{service_id}.{operation_model.name}'
# --> 132     self._event_emitter.emit(
#     133         event_name,
#     134         request=request,
#     135         operation_name=operation_model.name,
#     136     )
#     137 prepared_request = self.prepare_request(request)
#
# File /workspace/glaucoma-backend-2024/.venv/lib/python3.10/site-packages/botocore/hooks.py:412, in EventAliaser.emit(self, event_name, **kwargs)
#     411 aliased_event_name = self._alias_event_name(event_name)
# --> 412 return self._emitter.emit(aliased_event_name, **kwargs)
#
# File /workspace/glaucoma-backend-2024/.venv/lib/python3.10/site-packages/botocore/hooks.py:256, in HierarchicalEmitter.emit(self, event_name, **kwargs)
#     246 """
#     247 Emit an event by name with arguments passed as keyword args.
#     248
#    (...)
#     254          handlers.
#     255 """
# --> 256 return self._emit(event_name, kwargs)
#
# File /workspace/glaucoma-backend-2024/.venv/lib/python3.10/site-packages/botocore/hooks.py:239, in HierarchicalEmitter._emit(self, event_name, kwargs, stop_on_response)
#     238 logger.debug('Event %s: calling handler %s', event_name, handler)
# --> 239 response = handler(**kwargs)
#     240 responses.append((handler, response))
#
# File /workspace/glaucoma-backend-2024/.venv/lib/python3.10/site-packages/botocore/signers.py:105, in RequestSigner.handler(self, operation_name, request, **kwargs)
#     100 def handler(self, operation_name=None, request=None, **kwargs):
#     101     # This is typically hooked up to the "request-created" event
#     102     # from a client's event emitter.  When a new request is created
#     103     # this method is invoked to sign the request.
#     104     # Don't call this method directly.
# --> 105     return self.sign(operation_name, request)
#
# File /workspace/glaucoma-backend-2024/.venv/lib/python3.10/site-packages/botocore/signers.py:197, in RequestSigner.sign(self, operation_name, request, region_name, signing_type, expires_in, signing_name)
#     195         raise e
# --> 197 auth.add_auth(request)
#
# File /workspace/glaucoma-backend-2024/.venv/lib/python3.10/site-packages/botocore/auth.py:423, in SigV4Auth.add_auth(self, request)
#     422 if self.credentials is None:
# --> 423     raise NoCredentialsError()
#     424 datetime_now = datetime.datetime.utcnow()
#
# NoCredentialsError: Unable to locate credentials
#
# During handling of the above exception, another exception occurred:
#
# TableError                                Traceback (most recent call last)
# Cell In[1], line 22
#      18     tags = UnicodeSetAttribute()
#      19     last_post_datetime = UTCDateTimeAttribute()
# ---> 22 Thread2.exists()
#      23 #if not Thread.exists():
#      24 #    res = Thread.create_table(read_capacity_units=1, write_capacity_units=1, wait=True)
#
# File /workspace/glaucoma-backend-2024/.venv/lib/python3.10/site-packages/pynamodb/models.py:757, in Model.exists(cls)
#     753 """
#     754 Returns True if this table exists, False otherwise
#     755 """
#     756 try:
# --> 757     cls._get_connection().describe_table()
#     758     return True
#     759 except TableDoesNotExist:
#
# File /workspace/glaucoma-backend-2024/.venv/lib/python3.10/site-packages/pynamodb/connection/table.py:275, in TableConnection.describe_table(self)
#     271 def describe_table(self) -> Dict:
#     272     """
#     273     Performs the DescribeTable operation and returns the result
#     274     """
# --> 275     return self.connection.describe_table(self.table_name)
#
# File /workspace/glaucoma-backend-2024/.venv/lib/python3.10/site-packages/pynamodb/connection/base.py:636, in Connection.describe_table(self, table_name)
#     634     return table_data
#     635 except BotoCoreError as e:
# --> 636     raise TableError("Unable to describe table: {}".format(e), e)
#     637 except ClientError as e:
#     638     if 'ResourceNotFound' in e.response['Error']['Code']:
#
# TableError: Unable to describe table: Unable to locate credentials
